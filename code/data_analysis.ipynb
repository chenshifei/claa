# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv('../data/tweets_monolingual_5p.csv')
ax = sns.countplot(x='screen_name', data=df)

# %%
df.head()
# Out:
#                 id_str screen_name  \
# 0  1193152895337689088     YXSzzzz
# 1  1193152895337689088     YXSzzzz
# 2  1193152895337689088     YXSzzzz
# 3  1193152895337689088     YXSzzzz
# 4  1193152895337689088     YXSzzzz
#
#                                             raw_text  \
# 0    @gww067 Haha there is no way Ryza is not cute 😂
# 1  乳不平何以平天下!\nLess busty testing. https://t.co/Iy...
# 2                                @HrJasn 乳不巨何以聚人心 (誤
# 3  因為蠻多人問。。。我就統一發個 😂\nBecuz too many people ask ....
# 4  因為蠻多人問。。。我就統一發個 😂\nBecuz too many people ask ....
#
#                         chn_text  \
# 0                            NaN
# 1                      乳不平何以平天下!
# 2                      乳不巨何以聚人心誤
# 3  因為蠻多人問。。。我就統一發個這個是我自己無聊畫的，不是…
# 4  因為蠻多人問。。。我就統一發個這個是我自己無聊畫的，不是…
#
#                                             eng_text  \
# 0              Haha there is no way Ryza is not cute
# 1                                Less busty testing.
# 2                                                NaN
# ...

# %%
df.screen_name.value_counts().describe()
# Out:
# count      50.000000
# mean     1383.400000
# std      1211.125771
# min       102.000000
# 25%       334.500000
# 50%       856.000000
# 75%      2306.750000
# max      4195.000000
# Name: screen_name, dtype: float64

# %%
df.chn_text.drop_duplicates().str.len().describe()
# Out:
# count    27476.000000
# mean        37.663561
# std         29.142344
# min          5.000000
# 25%         16.000000
# 50%         27.000000
# 75%         51.000000
# max        140.000000
# Name: chn_text, dtype: float64

# %%
df.eng_text.drop_duplicates().str.len().describe()
# Out:
# count    37604.000000
# mean        72.589831
# std         31.038906
# min          6.000000
# 25%         47.000000
# 50%         74.000000
# 75%        100.000000
# max        146.000000
# Name: eng_text, dtype: float64

# %%
df.raw_text.str.len().describe()
# Out:
# count    69170.000000
# mean       100.309137
# std         38.240302
# min          5.000000
# 25%         68.000000
# 50%        109.000000
# 75%        140.000000
# max        159.000000
# Name: raw_text, dtype: float64

# %%
df.monolingual_text.str.len().describe()
# Out:
# count    69170.000000
# mean        57.327252
# std         34.584932
# min          5.000000
# 25%         26.000000
# 50%         52.000000
# 75%         87.000000
# max        146.000000
# Name: monolingual_text, dtype: float64
